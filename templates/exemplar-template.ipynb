# %% [markdown]
# ![Noteable.ac.uk Banner](https://raw.githubusercontent.com/YusufNik/Noteable/refs/heads/main/images/Noteable%20NB%20Header%20Banner.png)

# %% [markdown]
# ## Exemplar Information
#
# <div style="border:1px solid #b8daff; background:#d9edf7; color:#0c5460; padding:16px; margin:8px 0; border-radius:4px;">
#     <b>Purpose:</b> This notebook is a reusable exemplar template designed to help staff create clear, engaging, and pedagogically useful Jupyter/Noteable notebooks for teaching, learning, demonstration, or assessment support.
# </div>
# <div style="border:1px solid #c3e6cb; background:#d4edda; color:#155724; padding:16px; margin:8px 0; border-radius:4px;">
#     <b>Intended audience / teaching context:</b> Staff and teaching teams who want to design their own notebook exemplars for students, colleagues, workshops, courses, labs, revision materials, or self-paced learning activities.
# </div>
# <div style="border:1px solid #c3e6cb; background:#d4edda; color:#155724; padding:16px; margin:8px 0; border-radius:4px;">
#     <b>Noteable Requirements:</b><br>
#     <b>Environment:</b> [LIVE/BETA/DEV 2026/2027]<br>
#     <b>Server:</b> [Standard Python 3 / Language and Machine Learning / BioChemistry / GeoScience / Astronomy / R Studio / R with Stan]<br>
#     <b>Kernel:</b> [Python 3 / R]
# </div>
# <div style="border:1px solid #c3e6cb; background:#d4edda; color:#155724; padding:16px; margin:8px 0; border-radius:4px;">
#     <b>Required data or dependencies:</b><br>
#     - [e.g. Embedded fictional review dataset included directly in the notebook]<br>
#     - Python packages: [e.g. <code>pandas</code>, <code>matplotlib</code>, <code>plotly</code>, <code>ipywidgets</code>, <code>textblob</code>, <code>wordcloud</code>, <code>IPython</code>]<br>
#     - Standard library modules: [e.g. <code>re</code>, <code>string</code>, <code>warnings</code>, <code>collections</code>]
# </div>
# <div style="border:1px solid #ffeeba; background:#fff3cd; color:#856404; padding:16px; margin:8px 0; border-radius:4px;">
#     <b>Date created / last reviewed:</b> [dd Month yyyy]<br>
#     <b>Maintainer / owner:</b> [Full Name]
# </div>

# %% [markdown]
# # [INSERT CATCHY TITLE]: An Interactive Introduction
#
# ## Legend

# %% [markdown]
# <div style="border:1px solid #b8daff; background:#d9edf7; color:#0c5460; padding:16px; margin:8px 0; border-radius:4px;">
#     In <b>blue</b>, the <b>instructions</b> and <b>goals</b> are highlighted. This tells you what we are trying to achieve.
# </div>
# <div style="border:1px solid #c3e6cb; background:#d4edda; color:#155724; padding:16px; margin:8px 0; border-radius:4px;">
#     In <b>green</b>, key <b>information</b> and <b>concept explanations</b> are highlighted.
# </div>
# <div style="border:1px solid #ffeeba; background:#fff3cd; color:#856404; padding:16px; margin:8px 0; border-radius:4px;">
#     In <b>yellow</b>, <b>exercises</b> and <b>tasks</b> are highlighted for you to try yourself.
# </div>
# <div style="border:1px solid #f5c6cb; background:#f8d7da; color:#721c24; padding:16px; margin:8px 0; border-radius:4px;">
#     In <b>red</b>, <b>error interpretation</b> and <b>debugging tips</b> are highlighted.
# </div>

# %% [markdown]
# ## 1. Setting Up Our Toolkit
#
# <div style="border:1px solid #b8daff; background:#d9edf7; color:#0c5460; padding:16px; margin:8px 0; border-radius:4px;">
#     <b>Goal:</b> Import the tools we need for our journey. Python uses "libraries" (toolkits created by other programmers) to perform powerful tasks easily.
# </div>
#
# Click the code cell below and press the **<code>▶</code> Run** button located in the toolbar at the top (or `Shift + Enter`). We have included print statements so you know exactly when the computer finishes loading everything!

# %%
print("Starting setup: Importing libraries...")

# pandas helps us manage data
import pandas as pd

# matplotlib helps us draw graphs
import matplotlib.pyplot as plt

# ipywidgets allows us to create interactive sliders and buttons
import ipywidgets as widgets
from IPython.display import display, clear_output

print("Success! All libraries imported. You are ready to go!")

# %% [markdown]
# ## 2. [INSERT BASIC CONCEPT / PRIMER]
#
# <div style="border:1px solid #c3e6cb; background:#d4edda; color:#155724; padding:16px; margin:8px 0; border-radius:4px;">
#     <b>[CONCEPT TERM]:</b> This section demonstrates a core concept. Functions are reusable blocks of code that perform specific jobs.
# </div>
#
# Let's write some simple code to see this in action.

# %%
# A simple function demonstration
def calculate_doubles(value):
    result = value * 2
    print(f"The double of {value} is {result}")
    return

# Calling our function
value = 5 # Change value to 10
calculate_doubles(value)

# %% [markdown]
# <div style="border:1px solid #ffeeba; background:#fff3cd; color:#856404; padding:16px; margin:8px 0; border-radius:4px;">
#     <b>Exercise:</b> Change the code above so the value is <b>10</b> instead of 5. Press the <b><code>▶</code> Run</b> button again (or <code>Shift + Enter</code>) to see the new output!
# </div>

# %% [markdown]
# ## 3. Loading the Data
#
# <div style="border:1px solid #b8daff; background:#d9edf7; color:#0c5460; padding:16px; margin:8px 0; border-radius:4px;">
#     <b>Goal:</b> Load data so we have something to work with. Here, we will generate a standalone demo dataset.
# </div>

# %%
print("Fetching dataset... Please wait a moment.")

# Creating a simple standalone dataset for demonstration
data_dictionary = {
    'Category': ['A', 'B', 'C', 'D', 'E'],
    'Values': [10, 15, 7, 12, 18]
}
my_data = pd.DataFrame(data_dictionary)

print("Dataset loaded successfully! Here is a preview:")

# Display the top of the data
display(my_data.head())

# %% [markdown]
# ## 4. Error Interpretation & Debugging
#
# <div style="border:1px solid #f5c6cb; background:#f8d7da; color:#721c24; padding:16px; margin:8px 0; border-radius:4px;">
#     <b>Don't panic when you see red text!</b> Errors are just the computer asking for clarification. Learning to read them is a superpower. Let's look at a few common scenarios.
# </div>
#
# ### A. Warnings (The Non-Disruptive Alerts)
# Sometimes, Python gives you a heads-up that a tool is outdated. This generates a **Warning**, but your code will usually still run perfectly fine. *Note: We could hide these using `warnings.filterwarnings('ignore')`, but it's good practice to know they exist!*

# %%
import warnings

# Simulating a deprecation warning
warnings.warn("This specific function is old and might be removed in future versions!", DeprecationWarning)

print("See? The code still ran successfully down here!")

# %% [markdown]
# ### B. Import Errors (Missing Tools)
# If you try to load a library that isn't installed on your environment, you will get a `ModuleNotFoundError`.
#
# **How to fix it:** You can usually install it by typing `!pip install library_name` in a code cell, or `pip install library_name` in the terminal from the launcher.
#
# **Noteable Users:** If a core library you need is missing from this environment, please contact the EDINA Noteable team! They will look into updating the Notebook server presets for everyone.

# %%
print("Attempting to import a library that doesn't exist...")

# This will trigger an error!
import super_secret_fake_library_for_science

# %% [markdown]
# ### C. Isolated Syntax Errors
# Sometimes you just make a typo. Below, we forgot a closing parenthesis. This cell will fail, but notice how it doesn't break the entire notebook.
#
# <div style="border:1px solid #ffeeba; background:#fff3cd; color:#856404; padding:16px; margin:8px 0; border-radius:4px;">
#     <b>Fix It:</b> Add the missing <code>)</code> at the end of the print statement, then run the cell again!
# </div>

# %%
# Run this cell to see the SyntaxError, then fix it!
print("I am missing a closing bracket"

# %% [markdown]
# ### D. Cascading Errors
# Sometimes an error in one cell prevents important data from being created, which causes the *next* cell to fail. Below, we try to divide by zero, which stops the variable `important_calculation` from ever being saved.

# %%
# This cell fails because we can't divide by zero.
important_calculation = 100 / 0

print("This line will never print, because the error stopped the code above it.")

# %% [markdown]
# Because the cell above failed, the cell below will give a `NameError`—it has no idea what `important_calculation` is!
#
# <div style="border:1px solid #ffeeba; background:#fff3cd; color:#856404; padding:16px; margin:8px 0; border-radius:4px;">
#     <b>Fix It:</b> Go back to the cell above and change <code>100 / 0</code> to <code>100 / 2</code>. Run it, and then run the cell below again.
# </div>

# %%
# This fails until the cell above is fixed!
final_result = important_calculation + 50
print(f"The final result is: {final_result}")

# %% [markdown]
# ## 5. Visualising the Results
#
# <div style="border:1px solid #b8daff; background:#d9edf7; color:#0c5460; padding:16px; margin:8px 0; border-radius:4px;">
#     <b>Goal:</b> Use our visual tools to map out what this data actually means.
# </div>

# %%
print("Generating visualization > Please wait a moment...")

# Set up the size of the graph
plt.figure(figsize=(6, 4))

# Create a simple bar chart
plt.bar(my_data['Category'], my_data['Values'], color='#4C72B0')
plt.title("Demo Data Visualization")
plt.xlabel("Category")
plt.ylabel("Values")

print("Visualization generated successfully! Check it out below:\n")

# Show the graph
plt.show()

# %% [markdown]
# ## 6. Interactive Explorations
#
# <div style="border:1px solid #c3e6cb; background:#d4edda; color:#155724; padding:16px; margin:8px 0; border-radius:4px;">
#     <b>Interactivity:</b> Many libraries (like mapping or 3D tools) have interactivity built right in! For basic data, we can also use sliders to manipulate our graphs dynamically.
# </div>
#
# Run the cell below, and try using the controls to see how the output updates in real-time.

# %%
print("Building interactive widget...")

def interactive_function(multiplier):
    # Scale the data based on the slider
    updated_values = my_data['Values'] * multiplier
    
    plt.figure(figsize=(6, 4))
    plt.bar(my_data['Category'], updated_values, color='#55A868')
    plt.title(f"Values Multiplied by {multiplier}")
    plt.xlabel("Category")
    plt.ylabel("Scaled Values")
    plt.ylim(0, 100) # Lock the Y-axis so it doesn't jump around
    plt.show()

# Create the interactive slider
my_widget = widgets.IntSlider(
    value=1,
    min=1,
    max=5,
    step=1,
    description='Multiplier:',
    continuous_update=False
)

print("Widget ready! Use the controls below:\n")

# Display the widget linked to our function
widgets.interact(interactive_function, multiplier=my_widget);

# %% [markdown]
# ## Take-away
#
# <div style="border:1px solid #b8daff; background:#d9edf7; color:#0c5460; padding:16px; margin:8px 0; border-radius:4px;">
#     Congratulations! You've successfully completed this module. You've learned how to handle errors natively, read tracebacks, and interact with live data. Keep experimenting and having fun with Python!
# </div>

# %% [markdown]
# ![Noteable license](https://raw.githubusercontent.com/YusufNik/Noteable/refs/heads/main/images/Noteable%20Notebook%20Footer.png)
